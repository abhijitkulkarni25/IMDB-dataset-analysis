# %%
# %matplotlib inline
import pandas as pd

# %%
titles=pd.DataFrame.from_csv(r'C:\Users\abhij\Desktop\pycon-pandas-tutorial-master\data\titles.csv',index_col=None)
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2   The Spider and the Fly  1949
# 3                  Country  2000
# 4         Gai shi dao wang  1969

# %%
cast=pd.DataFrame.from_csv(r'C:\Users\abhij\Desktop\pycon-pandas-tutorial-master\data\cast.csv',index_col=None)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
dates=pd.DataFrame.from_csv(r'C:\Users\abhij\Desktop\pycon-pandas-tutorial-master\data\release_dates.csv',index_col=None)
dates.head()
# Out:
#                     title  year      country        date
# 0   #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                 #Beings  2015      Romania  2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# 3                 #Horror  2015          USA  2015-11-20
# 4                 #Horror  2015           UK  2016-05-16

# %% [markdown]
# # How many movies are listed in the titles dataframe?

# %%
len(titles['title'])
# Out:
# 235919

# %% [markdown]
# # What are the earliest two films listed in the titles dataframe?

# %%
titles.sort_values('year').head(2)
# Out:
#                      title  year
# 180545          Miss Jerry  1894
# 218555  The Startled Lover  1898

# %% [markdown]
# # How many movies have the title "Hamlet"?

# %%
len(titles[titles.title=='Hamlet'])
# Out:
# 20

# %% [markdown]
# # How many movies are titled "North by Northwest"?

# %%
len(titles[titles.title=='North by Northwest'])
# Out:
# 1

# %% [markdown]
# # When was the first movie titled "Hamlet" made?

# %%
titles[titles.title=='Hamlet'].sort_values('year').head(1)
# Out:
#         title  year
# 53572  Hamlet  1910

# %% [markdown]
# # List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles.title=='Treasure Island'].sort_values('year')
# Out:
#                   title  year
# 209202  Treasure Island  1918
# 52090   Treasure Island  1920
# 210840  Treasure Island  1934
# 98385   Treasure Island  1950
# 78412   Treasure Island  1972
# 113114  Treasure Island  1973
# 208560  Treasure Island  1985
# 182173  Treasure Island  1999

# %% [markdown]
# # How many movies were made in the year 1950?

# %%
len(titles[titles.year==1950])
# Out:
# 1111

# %% [markdown]
# # How many movies were made in the year 1960?

# %%
len(titles[titles.year==1960])
# Out:
# 1531

# %% [markdown]
# # How many movies were made from 1950 through 1959?

# %%
len(titles[(titles.year>=1950) & (titles.year<=1959)])
# Out:
# 12862

# %% [markdown]
# # In what years has a movie titled "Batman" been released?

# %%
c=titles[titles.title=='Batman']

# %%
c
# Out:
#         title  year
# 56907  Batman  1989
# 75748  Batman  1943

# %% [markdown]
# # How many roles were there in the movie "Inception"?

# %%
cast[cast.title=='Inception']
# Out:
#              title  year                     name     type  \
# 97536    Inception  2010     Michael (III) August    actor
# 148024   Inception  2010             Peter Basham    actor
# 182830   Inception  2010             Tom Berenger    actor
# 196675   Inception  2010                 Ken Bhan    actor
# 258552   Inception  2010           Virgile Bramly    actor
# 324905   Inception  2010            Michael Caine    actor
# 331556   Inception  2010             Earl Cameron    actor
# 372667   Inception  2010            John Ceallach    actor
# 431473   Inception  2010            Nicolas Clerc    actor
# 441963   Inception  2010           Adam (IV) Cole    actor
# 494495   Inception  2010             Garvin Cross    actor
# 514451   Inception  2010       Jean-Michel Dagory    actor
# 587351   Inception  2010        Leonardo DiCaprio    actor
# 680353   Inception  2010            Seve Esposito    actor
# 686870   Inception  2010      Marcus (II) Everett    actor
# ...

# %%
len(cast[cast.title=='Inception'])
# Out:
# 78

# %% [markdown]
# # How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
wow=cast[cast.title=='Inception']

# %%
len(wow[wow.n.isnull()])
# Out:
# 27

# %% [markdown]
# # But how many roles in the movie "Inception" did receive an "n" value?

# %%
len(wow[wow.n.notnull()])
# Out:
# 51

# %% [markdown]
# # Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
north=cast[cast.title=='North by Northwest']
north
# Out:
#                       title  year                  name     type  \
# 12603    North by Northwest  1959         Stanley Adams    actor
# 28910    North by Northwest  1959            Andy Albin    actor
# 56014    North by Northwest  1959          Don Anderson    actor
# 56233    North by Northwest  1959       Ernest Anderson    actor
# 95340    North by Northwest  1959     Malcolm Atterbury    actor
# 101130   North by Northwest  1959             Tol Avery    actor
# 112792   North by Northwest  1959            Sam Bagley    actor
# 118296   North by Northwest  1959           Frank Baker    actor
# 124114   North by Northwest  1959             Alex Ball    actor
# 142408   North by Northwest  1959         Baynes Barron    actor
# 156939   North by Northwest  1959         Brandon Beach    actor
# 182004   North by Northwest  1959         John Beradino    actor
# 205204   North by Northwest  1959          Edward Binns    actor
# ...

# %%
north1=north[north.n.notnull()].sort_values('n')

# %%
north1
# Out:
#                       title  year                  name     type  \
# 866585   North by Northwest  1959            Cary Grant    actor
# 3470369  North by Northwest  1959       Eva Marie Saint  actress
# 1448535  North by Northwest  1959           James Mason    actor
# 3121299  North by Northwest  1959   Jessie Royce Landis  actress
# 354773   North by Northwest  1959        Leo G. Carroll    actor
# 3016457  North by Northwest  1959  Josephine Hutchinson  actress
# 1685239  North by Northwest  1959           Philip Ober    actor
# 1267591  North by Northwest  1959         Martin Landau    actor
# 2432534  North by Northwest  1959         Adam Williams    actor
# 1800621  North by Northwest  1959          Edward Platt    actor
# 662117   North by Northwest  1959     Robert Ellenstein    actor
# 2282075  North by Northwest  1959          Les Tremayne    actor
# 462192   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# # Display the entire cast, in "n"-order, of the 1972 film "Sleuth"

# %%
sleuth=cast[cast.title=='Sleuth'].sort_values('n')

# %%
sleuth
# Out:
#           title  year                 name     type  \
# 324934   Sleuth  2007        Michael Caine    actor
# 1695323  Sleuth  1972     Laurence Olivier    actor
# 324933   Sleuth  1972        Michael Caine    actor
# 1285773  Sleuth  2007             Jude Law    actor
# 371888   Sleuth  1972       Alec Cawthorne    actor
# 1795184  Sleuth  2007        Harold Pinter    actor
# 1456765  Sleuth  1972   John (II) Matthews    actor
# 2702931  Sleuth  1972   Eve (III) Channing  actress
# 1440103  Sleuth  1972         Teddy Martin    actor
# 258665   Sleuth  2007      Kenneth Branagh    actor
# 371889   Sleuth  2007  Alec (II) Cawthorne    actor
# 2702930  Sleuth  2007    Eve (II) Channing  actress
# 3327430  Sleuth  2007    Carmel O'Sullivan  actress
#
#                           character    n
# 324934                       Andrew  1.0
# 1695323                 Andrew Wyke  1.0
# 324933                  Milo Tindle  2.0
# 1285773                        Milo  2.0
# ...

# %%
sleuth[sleuth.year==1972]
# Out:
#           title  year                name     type  \
# 1695323  Sleuth  1972    Laurence Olivier    actor
# 324933   Sleuth  1972       Michael Caine    actor
# 371888   Sleuth  1972      Alec Cawthorne    actor
# 1456765  Sleuth  1972  John (II) Matthews    actor
# 2702931  Sleuth  1972  Eve (III) Channing  actress
# 1440103  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1695323                 Andrew Wyke  1.0
# 324933                  Milo Tindle  2.0
# 371888            Inspector Doppler  3.0
# 1456765  Detective Sergeant Tarrant  4.0
# 2702931             Marguerite Wyke  5.0
# 1440103      Police Constable Higgs  6.0

# %% [markdown]
# # Display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
sleuth[sleuth.year==2007]
# Out:
#           title  year                 name     type          character    n
# 324934   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1285773  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1795184  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 258665   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 371889   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2702930  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3327430  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# # How many roles were credited in the silent 1921 version of Hamlet?

# %%
hamlet=cast[(cast.title=='Hamlet') & (cast.year==1921)].sort_values('n')

# %%
hamlet
# Out:
#           title  year                    name     type         character    n
# 3312681  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0
# 456392   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 2644784  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2361744  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2172557  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 1129000  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 552058   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 3029675  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 7759     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0

# %%
len(hamlet)
# Out:
# 9

# %% [markdown]
# # How many roles were credited in Branagh’s 1996 Hamlet?

# %%
len(cast[(cast.title=='Hamlet') & (cast.year==1996)])
# Out:
# 54

# %% [markdown]
# # How many "Hamlet" roles have been listed in all film credits through history?

# %%
len(cast[cast.character=='Hamlet'])
# Out:
# 95

# %% [markdown]
# # How many people have played an "Ophelia"?

# %%
len(cast[cast.character=='Ophelia'].name.unique())
# Out:
# 111

# %% [markdown]
# # How many people have played a role called "The Dude"?

# %%
len(cast[cast.character=='The Dude'].name.unique())
# Out:
# 18

# %% [markdown]
# # How many people have played the role called "The Stranger"

# %%
len(cast[cast.character=='The Stranger'].name.unique())
# Out:
# 203

# %% [markdown]
# # How many roles has Sidney Poitier played throughout his career?

# %%
len(cast[cast.name=='Sidney Poitier'].character.unique())
# Out:
# 41

# %% [markdown]
# # How many roles has Judi Dench played?

# %%
len(cast[cast.name=='Judi Dench'])
# Out:
# 54

# %% [markdown]
# # List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
carry=cast[(cast.name=='Cary Grant') & (cast.n==2)].sort_values('year')

# %%
carry
# Out:
#                          title  year        name   type  \
# 866576        Madame Butterfly  1932  Cary Grant  actor
# 866595      She Done Him Wrong  1933  Cary Grant  actor
# 866613       The Woman Accused  1933  Cary Grant  actor
# 866605  The Eagle and the Hawk  1933  Cary Grant  actor
# 866570            I'm No Angel  1933  Cary Grant  actor
# 866614     Thirty-Day Princess  1934  Cary Grant  actor
# 866551          Born to Be Bad  1934  Cary Grant  actor
# 866599         Sylvia Scarlett  1935  Cary Grant  actor
# 866559           Enter Madame!  1935  Cary Grant  actor
# 866624       Wings in the Dark  1935  Cary Grant  actor
# 866622         Wedding Present  1936  Cary Grant  actor
# 866623     When You're in Love  1937  Cary Grant  actor
# 866602         The Awful Truth  1937  Cary Grant  actor
# 866612   The Toast of New York  1937  Cary Grant  actor
# 866618                  Topper  1937  Cary Grant  actor
# 866566                 Holiday  1938  Cary Grant  actor
# ...

# %%
carry[carry.year//10==194]
# Out:
#                    title  year        name   type    character    n
# 866582  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 866592    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# # List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cary1=cast[(cast.name=='Cary Grant') & (cast.n==1)].sort_values('year')

# %%
cary1[cary1.year//10==194]
# Out:
#                                        title  year        name   type  \
# 866609                The Philadelphia Story  1940  Cary Grant  actor
# 866565                       His Girl Friday  1940  Cary Grant  actor
# 866607               The Howards of Virginia  1940  Cary Grant  actor
# 866597                             Suspicion  1941  Cary Grant  actor
# 866588                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 866611                  The Talk of the Town  1942  Cary Grant  actor
# 866581                             Mr. Lucky  1943  Cary Grant  actor
# 866556                     Destination Tokyo  1943  Cary Grant  actor
# 866580                             Mr. Lucky  1943  Cary Grant  actor
# 866548                  Arsenic and Old Lace  1944  Cary Grant  actor
# 866589                      Once Upon a Time  1944  Cary Grant  actor
# 866584             None But the Lonely Heart  1944  Cary Grant  actor
# ...

# %% [markdown]
# # How many roles were available for actors in the 1950s?

# %%
len(cast[(cast.type=='actor') & (cast.year//10==195)])
# Out:
# 157189

# %% [markdown]
# # How many roles were avilable for actresses in the 1950s?

# %%
len(cast[(cast.type=='actress') & (cast.year//10==195)])
# Out:
# 57152

# %% [markdown]
# # How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
len(cast[(cast.year<=1980) & (cast.n==1)])
# Out:
# 64757

# %% [markdown]
# # How many non-leading roles were available through from the beginning of film history through 1980?

# %%
len(cast[(cast.year<=1980) & (cast.n!=1)])
# Out:
# 1109929

# %% [markdown]
# # How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
len(cast[(cast.year<=1980) & (cast.n.isnull())])
# Out:
# 445087
