# %%
# %matplotlib inline
import pandas as pd

# %%
titles=pd.DataFrame.from_csv(r'C:\Users\abhij\Desktop\pycon-pandas-tutorial-master\data\titles.csv',index_col=None)

# %%
titles
# Out:
#                                      title  year
# 0                           The Rising Son  1990
# 1                  The Thousand Plane Raid  1969
# 2                   The Spider and the Fly  1949
# 3                                  Country  2000
# 4                         Gai shi dao wang  1969
# 5                               Gaiking II  2011
# 6                              Medusa (IV)  2015
# 7           The Fresh Air Will Do You Good  2008
# 8                       Alex in Wonderland  1970
# 9                               L'outsider  2016
# 10                           Death Ouija 2  2017
# 11                  Do Outro Lado do Mundo  2008
# 12                           Slave by Name  2017
# 13                          The Abductress  2014
# 14                Poka Makorer Ghar Bosoti  1996
# 15                               Hi, Buddy  1943
# 16                         Los siete locos  1973
# 17                              Panic Room  2002
# ...

# %%
cast=pd.DataFrame.from_csv(r'C:\Users\abhij\Desktop\pycon-pandas-tutorial-master\data\cast.csv',index_col=None)
cast
# Out:
#                                                      title  year  \
# 0                                           Closet Monster  2015
# 1                                          Suuri illusioni  1985
# 2                                      Battle of the Sexes  2017
# 3                                     Secret in Their Eyes  2015
# 4                                               Steve Jobs  2015
# 5                                   Straight Outta Compton  2015
# 6                                   Straight Outta Compton  2015
# 7                                           For Thy Love 2  2009
# 8        Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                             Desire (III)  2014
# 10                                 When the Man Went South  2014
# 11                                 Little Angel (Angelita)  2015
# 12                                              Mixing Nia  1998
# ...

# %%
dates1=pd.DataFrame.from_csv(r'C:\Users\abhij\Desktop\pycon-pandas-tutorial-master\data\release_dates.csv',index_col=None)
dates1
# Out:
#                           title  year         country        date
# 0         #73, Shaanthi Nivaasa  2007           India  2007-06-15
# 1                       #Beings  2015         Romania  2015-01-29
# 2        #Ewankosau saranghaeyo  2015     Philippines  2015-01-21
# 3                       #Horror  2015             USA  2015-11-20
# 4                       #Horror  2015              UK  2016-05-16
# 5                 #Lucky Number  2015             USA  2015-09-01
# 6            #Nerealnaya lyubov  2014          Russia  2014-02-13
# 7                #Pellichoopulu  2016           India  2016-07-29
# 8                    #Screamers  2016             USA  2017-10-31
# 9                     #Sequence  2013           Spain  2013-12-21
# 10                       #Stuck  2014          Turkey  2014-07-01
# 11                       #Stuck  2014             USA  2014-10-10
# 12                 #WszystkoGra  2016          Poland  2016-05-06
# ...

# %%
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2   The Spider and the Fly  1949
# 3                  Country  2000
# 4         Gai shi dao wang  1969

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
dates1.head()
# Out:
#                     title  year      country        date
# 0   #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                 #Beings  2015      Romania  2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# 3                 #Horror  2015          USA  2015-11-20
# 4                 #Horror  2015           UK  2016-05-16

# %%
dates1.tail()
# Out:
#                           title  year  country        date
# 465209  xXx: State of the Union  2005  Uruguay  2005-04-29
# 465210  xXx: State of the Union  2005   Poland  2005-06-03
# 465211  xXx: State of the Union  2005   Turkey  2005-06-03
# 465212  xXx: State of the Union  2005    China  2005-06-17
# 465213  xXx: State of the Union  2005   Greece  2005-06-24

# %%
cast.tail()
# Out:
#                                     title  year                         name  \
# 3729241                           Foxtrot  1988            Lilja ??risd?ttir
# 3729242  Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3729243                         Skammdegi  1985           Dalla ??r?ard?ttir
# 3729244                      U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3729245                 Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
#             type               character     n
# 3729241  actress                    D?ra  24.0
# 3729242  actress            Woman in Bus  26.0
# 3729243  actress           Hj?krunarkona   9.0
# 3729244  actress  Afgr.dama ? bens?nst??  17.0
# 3729245  actress       Pensionatv?rtinde   NaN

# %%
titles.tail()
# Out:
#                        title  year
# 235914                 E yue  2005
# 235915          Lakota Girls  2015
# 235916        Kroniki domowe  1997
# 235917  Awakening the Zodiac  2017
# 235918        American Satan  2017

# %%
len(titles)
# Out:
# 235919

# %%
len(cast)
# Out:
# 3729246

# %%
len(dates1)
# Out:
# 465214

# %%
c0=cast.head(1)

# %%
c0
# Out:
#             title  year      name   type character     n
# 0  Closet Monster  2015  Buffy #1  actor   Buffy 4  31.0

# %%
t0=titles.head(1)
t0
# Out:
#             title  year
# 0  The Rising Son  1990

# %%
d0=dates1.head(1)
d0
# Out:
#                    title  year country        date
# 0  #73, Shaanthi Nivaasa  2007   India  2007-06-15

# %%
h1=cast.head()

# %%
h1
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
t1=titles.head()
t1
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2   The Spider and the Fly  1949
# 3                  Country  2000
# 4         Gai shi dao wang  1969

# %%
t1[t1['year']==1990]
# Out:
#             title  year
# 0  The Rising Son  1990

# %%
t1['year']//10*10
# Out:
# 0    1990
# 1    1960
# 2    1940
# 3    2000
# 4    1960
# Name: year, dtype: int64

# %%
t1.year
# Out:
# 0    1990
# 1    1969
# 2    1949
# 3    2000
# 4    1969
# Name: year, dtype: int64

# %%
titles.year
# Out:
# 0         1990
# 1         1969
# 2         1949
# 3         2000
# 4         1969
# 5         2011
# 6         2015
# 7         2008
# 8         1970
# 9         2016
# 10        2017
# 11        2008
# 12        2017
# 13        2014
# 14        1996
# 15        1943
# 16        1973
# 17        2002
# 18        1976
# 19        2012
# 20        1965
# 21        1999
# 22        1917
# 23        2009
# 24        1989
# 25        2016
# 26        1993
# 27        2011
# 28        1916
# 29        1990
#           ...
# 235889    1980
# 235890    1990
# 235891    2015
# 235892    1981
# 235893    1966
# 235894    1980
# 235895    2013
# 235896    2013
# 235897    1991
# 235898    1932
# 235899    1986
# 235900    2018
# 235901    2005
# 235902    2004
# 235903    1981
# 235904    2013
# 235905    2016
# 235906    2017
# 235907    2004
# 235908    1984
# 235909    2012
# 235910    2001
# 235911    1973
# 235912    1982
# 235913    1964
# 235914    2005
# 235915    2015
# ...

# %%
titles[titles.year<1985]
# Out:
#                                                     title  year
# 1                                 The Thousand Plane Raid  1969
# 2                                  The Spider and the Fly  1949
# 4                                        Gai shi dao wang  1969
# 8                                      Alex in Wonderland  1970
# 15                                              Hi, Buddy  1943
# 16                                        Los siete locos  1973
# 18                                  Io sono un autarchico  1976
# 20                                             Mahapurush  1965
# 22                                                 Patria  1917
# 28                           Suzanne, professeur de flirt  1916
# 30                                              Firstborn  1984
# 42                 La momia azteca contra el robot humano  1958
# 45                                     The Fair Pretender  1918
# 47                                            Mavi boncuk  1958
# ...

# %%
f=titles[(titles.year>1980) & (titles.year<=2000)]

# %%
f
# Out:
#                                              title  year
# 0                                   The Rising Son  1990
# 3                                          Country  2000
# 14                        Poka Makorer Ghar Bosoti  1996
# 21                                Maa Durga Shakti  1999
# 24                     Ang pumatay ng dahil sa iyo  1989
# 26                            Conflict of Interest  1993
# 29                                    Arrive Alive  1990
# 30                                       Firstborn  1984
# 34                                     Der Brocken  1992
# 37                                       The Court  1998
# 38      The Neverending Story II: The Next Chapter  1990
# 40                                   Meigui xuanwo  2000
# 43                                        Safe Sex  1999
# 49                                      Torn Apart  1990
# 54                             Sabse Bada Be-Imaan  2000
# ...

# %%
t=titles
t[t.title=='Titanic'].sort_values('year')
# Out:
#           title  year
# 123579  Titanic  1915
# 93710   Titanic  1943
# 7854    Titanic  1953
# 59484   Titanic  1997
# 175381  Titanic  2012

# %%
t.year
# Out:
# 0         1990
# 1         1969
# 2         1949
# 3         2000
# 4         1969
# 5         2011
# 6         2015
# 7         2008
# 8         1970
# 9         2016
# 10        2017
# 11        2008
# 12        2017
# 13        2014
# 14        1996
# 15        1943
# 16        1973
# 17        2002
# 18        1976
# 19        2012
# 20        1965
# 21        1999
# 22        1917
# 23        2009
# 24        1989
# 25        2016
# 26        1993
# 27        2011
# 28        1916
# 29        1990
#           ...
# 235889    1980
# 235890    1990
# 235891    2015
# 235892    1981
# 235893    1966
# 235894    1980
# 235895    2013
# 235896    2013
# 235897    1991
# 235898    1932
# 235899    1986
# 235900    2018
# 235901    2005
# 235902    2004
# 235903    1981
# 235904    2013
# 235905    2016
# 235906    2017
# 235907    2004
# 235908    1984
# 235909    2012
# 235910    2001
# 235911    1973
# 235912    1982
# 235913    1964
# 235914    2005
# 235915    2015
# ...

# %%
c0
# Out:
#             title  year      name   type character     n
# 0  Closet Monster  2015  Buffy #1  actor   Buffy 4  31.0

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
h=cast.head()

# %%
h1=h[h.n.notnull()]

# %%
h1
# Out:
#                  title  year      name   type        character     n
# 0       Closet Monster  2015  Buffy #1  actor          Buffy 4  31.0
# 1      Suuri illusioni  1985    Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017   $hutter  actor  Bobby Riggs Fan  10.0

# %%
h2=h[h.n.isnull()]

# %%
h2
# Out:
#                   title  year     name   type                character   n
# 3  Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan NaN
# 4            Steve Jobs  2015  $hutter  actor  1988 Opera House Patron NaN

# %%
titles[titles.title=='Titanic'].sort_values('year')
# Out:
#           title  year
# 123579  Titanic  1915
# 93710   Titanic  1943
# 7854    Titanic  1953
# 59484   Titanic  1997
# 175381  Titanic  2012

# %%
titles['title']
# Out:
# 0                             The Rising Son
# 1                    The Thousand Plane Raid
# 2                     The Spider and the Fly
# 3                                    Country
# 4                           Gai shi dao wang
# 5                                 Gaiking II
# 6                                Medusa (IV)
# 7             The Fresh Air Will Do You Good
# 8                         Alex in Wonderland
# 9                                 L'outsider
# 10                             Death Ouija 2
# 11                    Do Outro Lado do Mundo
# 12                             Slave by Name
# 13                            The Abductress
# 14                  Poka Makorer Ghar Bosoti
# 15                                 Hi, Buddy
# 16                           Los siete locos
# 17                                Panic Room
# 18                     Io sono un autarchico
# 19                    Shobhna's Seven Nights
# 20                                Mahapurush
# ...

# %%
titles.year
# Out:
# 0         1990
# 1         1969
# 2         1949
# 3         2000
# 4         1969
# 5         2011
# 6         2015
# 7         2008
# 8         1970
# 9         2016
# 10        2017
# 11        2008
# 12        2017
# 13        2014
# 14        1996
# 15        1943
# 16        1973
# 17        2002
# 18        1976
# 19        2012
# 20        1965
# 21        1999
# 22        1917
# 23        2009
# 24        1989
# 25        2016
# 26        1993
# 27        2011
# 28        1916
# 29        1990
#           ...
# 235889    1980
# 235890    1990
# 235891    2015
# 235892    1981
# 235893    1966
# 235894    1980
# 235895    2013
# 235896    2013
# 235897    1991
# 235898    1932
# 235899    1986
# 235900    2018
# 235901    2005
# 235902    2004
# 235903    1981
# 235904    2013
# 235905    2016
# 235906    2017
# 235907    2004
# 235908    1984
# 235909    2012
# 235910    2001
# 235911    1973
# 235912    1982
# 235913    1964
# 235914    2005
# 235915    2015
# ...

# %%
titles.year>1985
# Out:
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
# 5          True
# 6          True
# 7          True
# 8         False
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15        False
# 16        False
# 17         True
# 18        False
# 19         True
# 20        False
# 21         True
# 22        False
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28        False
# 29         True
#           ...
# 235889    False
# 235890     True
# 235891     True
# 235892    False
# 235893    False
# 235894    False
# 235895     True
# 235896     True
# 235897     True
# 235898    False
# 235899     True
# 235900     True
# 235901     True
# 235902     True
# 235903    False
# 235904     True
# 235905     True
# 235906     True
# 235907     True
# 235908    False
# 235909     True
# 235910     True
# 235911    False
# 235912    False
# ...

# %%
t1=titles[(titles.year>1998) & (titles.year<=2000)]

# %%
t1.sort_values('year').tail()
# Out:
#                                 title  year
# 98266                  A ruota libera  2000
# 98478   The Sunshine Deli and Grocery  2000
# 98592                  Under Pressure  2000
# 96348                  Bring Him Home  2000
# 115430                      Supernova  2000

# %%
h=cast.head()
h1=h[h.n.isnull()]

# %%
h1
# Out:
#                   title  year     name   type                character   n
# 3  Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan NaN
# 4            Steve Jobs  2015  $hutter  actor  1988 Opera House Patron NaN

# %%
h2=h[h.n.notnull()]

# %%
h2
# Out:
#                  title  year      name   type        character     n
# 0       Closet Monster  2015  Buffy #1  actor          Buffy 4  31.0
# 1      Suuri illusioni  1985    Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017   $hutter  actor  Bobby Riggs Fan  10.0

# %%
c=titles
c[c.title=='Speed'].sort_values('year')
# Out:
#         title  year
# 99558   Speed  1922
# 6432    Speed  1936
# 35043   Speed  1994
# 63244   Speed  2007
# 224185  Speed  2015

# %%
'Pulp Fiction'.startswith('Pulp')
# Out:
# True

# %%
c[c.title.str.startswith('The')]
# Out:
#                                                 title  year
# 0                                      The Rising Son  1990
# 1                             The Thousand Plane Raid  1969
# 2                              The Spider and the Fly  1949
# 7                      The Fresh Air Will Do You Good  2008
# 13                                     The Abductress  2014
# 27                                      The Syndicate  2011
# 31            The Majestic Life of Queen Elizabeth II  2013
# 35                                  The Hidden Corner  2016
# 37                                          The Court  1998
# 38         The Neverending Story II: The Next Chapter  1990
# 45                                 The Fair Pretender  1918
# 57                                 The Forgotten Five  2015
# 61                              The Amityville Horror  2005
# 102                                 The Ridin' Rascal  1926
# 103                         The Firefly of Tough Luck  1917
# ...

# %%
w=titles.year.value_counts().sort_index()

# %%
w
# Out:
# 1894        1
# 1898        1
# 1899        1
# 1900        5
# 1903        1
# 1905        2
# 1906        5
# 1907        5
# 1908        6
# 1909       15
# 1910       23
# 1911       54
# 1912      111
# 1913      246
# 1914      563
# 1915      886
# 1916     1190
# 1917     1210
# 1918     1103
# 1919     1171
# 1920     1133
# 1921      978
# 1922      900
# 1923      746
# 1924      803
# 1925      889
# 1926      874
# 1927      880
# 1928      893
# 1929      766
#         ...
# 1999     2535
# 2000     2751
# 2001     2876
# 2002     2996
# 2003     3157
# 2004     3485
# 2005     3993
# 2006     4257
# 2007     4420
# 2008     5101
# 2009     6079
# 2010     6372
# 2011     6935
# 2012     7353
# 2013     7796
# 2014     8189
# 2015     8578
# 2016     9436
# 2017    10669
# 2018     3741
# 2019      289
# 2020       73
# 2021       19
# 2022        9
# 2023        1
# 2024        4
# 2025        2
# 2026        1
# 2027        3
# 2115        1
# ...

# %%
w.plot(c='r')

# %%
c=cast

# %%
c
# Out:
#                                                      title  year  \
# 0                                           Closet Monster  2015
# 1                                          Suuri illusioni  1985
# 2                                      Battle of the Sexes  2017
# 3                                     Secret in Their Eyes  2015
# 4                                               Steve Jobs  2015
# 5                                   Straight Outta Compton  2015
# 6                                   Straight Outta Compton  2015
# 7                                           For Thy Love 2  2009
# 8        Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                             Desire (III)  2014
# 10                                 When the Man Went South  2014
# 11                                 Little Angel (Angelita)  2015
# 12                                              Mixing Nia  1998
# ...

# %%
kermit=c[c.character=='Kermit the Frog'].sort_index()

# %%
kermit
# Out:
#                                   title  year            name   type  \
# 977109   An American Werewolf in London  1981      Jim Henson  actor
# 977110                 Follow That Bird  1985      Jim Henson  actor
# 977115           The Great Muppet Caper  1981      Jim Henson  actor
# 977123                 The Muppet Movie  1979      Jim Henson  actor
# 977130       The Muppets Take Manhattan  1984      Jim Henson  actor
# 2423489  Mr. Magorium's Wonder Emporium  2007  Steve Whitmire  actor
# 2423490          Muppet Treasure Island  1996  Steve Whitmire  actor
# 2423493              Muppets from Space  1999  Steve Whitmire  actor
# 2423499             Muppets Most Wanted  2014  Steve Whitmire  actor
#
#                character     n
# 977109   Kermit the Frog  18.0
# 977110   Kermit the Frog   2.0
# 977115   Kermit the Frog   1.0
# 977123   Kermit the Frog   1.0
# 977130   Kermit the Frog   1.0
# 2423489  Kermit the Frog   8.0
# 2423490  Kermit the Frog  10.0
# ...

# %%
kermit.plot(x='year',y='n',kind='scatter',c='g')

# %%
import hashlib
with open (r'C:\Users\abhij\Desktop\pycon-pandas-tutorial-master\data\titles.csv','rb') as f:
    print (hashlib.md5(f.read()).hexdigest())
# Out:
# 68d3056391022e6c11e2f38fda8d85ca

# %%
cast[cast.title=='Sleuth'].sort_values('year')
# Out:
#           title  year                 name     type  \
# 324933   Sleuth  1972        Michael Caine    actor
# 371888   Sleuth  1972       Alec Cawthorne    actor
# 1440103  Sleuth  1972         Teddy Martin    actor
# 1456765  Sleuth  1972   John (II) Matthews    actor
# 1695323  Sleuth  1972     Laurence Olivier    actor
# 2702931  Sleuth  1972   Eve (III) Channing  actress
# 258665   Sleuth  2007      Kenneth Branagh    actor
# 324934   Sleuth  2007        Michael Caine    actor
# 371889   Sleuth  2007  Alec (II) Cawthorne    actor
# 1285773  Sleuth  2007             Jude Law    actor
# 1795184  Sleuth  2007        Harold Pinter    actor
# 2702930  Sleuth  2007    Eve (II) Channing  actress
# 3327430  Sleuth  2007    Carmel O'Sullivan  actress
#
#                           character    n
# 324933                  Milo Tindle  2.0
# 371888            Inspector Doppler  3.0
# 1440103      Police Constable Higgs  6.0
# 1456765  Detective Sergeant Tarrant  4.0
# ...

# %% [markdown]
# # How long did the above computation take?

# %%
# %%time 
cast[cast.title=='Sleuth'].sort_values('year')
# Out:
# Wall time: 358 ms
#           title  year                 name     type  \
# 324933   Sleuth  1972        Michael Caine    actor
# 371888   Sleuth  1972       Alec Cawthorne    actor
# 1440103  Sleuth  1972         Teddy Martin    actor
# 1456765  Sleuth  1972   John (II) Matthews    actor
# 1695323  Sleuth  1972     Laurence Olivier    actor
# 2702931  Sleuth  1972   Eve (III) Channing  actress
# 258665   Sleuth  2007      Kenneth Branagh    actor
# 324934   Sleuth  2007        Michael Caine    actor
# 371889   Sleuth  2007  Alec (II) Cawthorne    actor
# 1285773  Sleuth  2007             Jude Law    actor
# 1795184  Sleuth  2007        Harold Pinter    actor
# 2702930  Sleuth  2007    Eve (II) Channing  actress
# 3327430  Sleuth  2007    Carmel O'Sullivan  actress
#
#                           character    n
# 324933                  Milo Tindle  2.0
# 371888            Inspector Doppler  3.0
# 1440103      Police Constable Higgs  6.0
# 1456765  Detective Sergeant Tarrant  4.0
# ...

# %% [markdown]
# # It took around 358 ms to parse through 3729245 rows of data

# %%
c=cast.set_index(['title'])
c
# Out:
#                                                    year  \
# title
# Closet Monster                                     2015
# Suuri illusioni                                    1985
# Battle of the Sexes                                2017
# Secret in Their Eyes                               2015
# Steve Jobs                                         2015
# Straight Outta Compton                             2015
# Straight Outta Compton                             2015
# For Thy Love 2                                     2009
# Lapis, Ballpen at Diploma, a True to Life Journey  2014
# Desire (III)                                       2014
# When the Man Went South                            2014
# Little Angel (Angelita)                            2015
# Mixing Nia                                         1998
# The Replacements                                   2000
# All Out Dysfunktion!                               2016
# Gook                                               2017
# ...

# %%
# %%time
c.loc['Sleuth']
# Out:
# Wall time: 146 ms
#         year                 name     type                   character    n
# title
# Sleuth  2007      Kenneth Branagh    actor           Other Man on T.V.  NaN
# Sleuth  1972        Michael Caine    actor                 Milo Tindle  2.0
# Sleuth  2007        Michael Caine    actor                      Andrew  1.0
# Sleuth  1972       Alec Cawthorne    actor           Inspector Doppler  3.0
# Sleuth  2007  Alec (II) Cawthorne    actor           Inspector Doppler  NaN
# Sleuth  2007             Jude Law    actor                        Milo  2.0
# Sleuth  1972         Teddy Martin    actor      Police Constable Higgs  6.0
# Sleuth  1972   John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# Sleuth  1972     Laurence Olivier    actor                 Andrew Wyke  1.0
# Sleuth  2007        Harold Pinter    actor                 Man on T.V.  3.0
# Sleuth  2007    Eve (II) Channing  actress             Marguerite Wyke  NaN
# ...

# %%
c=cast.set_index(['title','year']).sort_index()

# %%
c.head()
# Out:
#                                     name   type               character     n
# title            year
# #1 Serial Killer 2013      Michael Alton  actor       Detective Roberts  17.0
#                  2013         Aaron Aoki  actor      Plastic Bag Victim  21.0
#                  2013  Zachary (X) Brown  actor  Africian American Teen  18.0
#                  2013     Yvis Cannavale  actor            Homeless Man  25.0
#                  2013      Patrick Chien  actor          Cleaver Victim  22.0

# %%
# %%time
c.loc['Sleuth',1972]
# Out:
# Wall time: 237 ms
#                            name     type                   character    n
# title  year
# Sleuth 1972       Michael Caine    actor                 Milo Tindle  2.0
#        1972      Alec Cawthorne    actor           Inspector Doppler  3.0
#        1972        Teddy Martin    actor      Police Constable Higgs  6.0
#        1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
#        1972    Laurence Olivier    actor                 Andrew Wyke  1.0
#        1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
f1=c.loc[('Sleuth',1972)].reset_index(['year','title'])

# %%
f1
# Out:
#     title  year                name     type                   character    n
# 0  Sleuth  1972       Michael Caine    actor                 Milo Tindle  2.0
# 1  Sleuth  1972      Alec Cawthorne    actor           Inspector Doppler  3.0
# 2  Sleuth  1972        Teddy Martin    actor      Police Constable Higgs  6.0
# 3  Sleuth  1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# 4  Sleuth  1972    Laurence Olivier    actor                 Andrew Wyke  1.0
# 5  Sleuth  1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
c=cast

# %%
c1=c[c.name=='George Clooney'].sort_index()

# %%
c1
# Out:
#                                      title  year            name   type  \
# 433326                      Batman & Robin  1997  George Clooney  actor
# 433327                      Batman & Robin  1997  George Clooney  actor
# 433328                  Burn After Reading  2008  George Clooney  actor
# 433329     Confessions of a Dangerous Mind  2002  George Clooney  actor
# 433330                             Curdled  1996  George Clooney  actor
# 433331                   Fantastic Mr. Fox  2009  George Clooney  actor
# 433332                 From Dusk Till Dawn  1996  George Clooney  actor
# 433333          Good Night, and Good Luck.  2005  George Clooney  actor
# 433334                             Gravity  2013  George Clooney  actor
# 433335             Grizzly II: The Concert  1983  George Clooney  actor
# 433336                       Hail, Caesar!  2016  George Clooney  actor
# 433337                 Intolerable Cruelty  2003  George Clooney  actor
# ...

# %%
c1.plot(x='year',y='n',kind='scatter')

# %%
#GroupBy(this is very crucial)(it is a Pandas series)
c1.groupby(['title','year','character']).size()
# Out:
# title                               year  character
# Batman & Robin                      1997  Batman                      1
#                                           Bruce Wayne                 1
# Burn After Reading                  2008  Harry Pfarrer               1
# Confessions of a Dangerous Mind     2002  Jim Byrd                    1
# Curdled                             1996  Seth Gecko                  1
# Fantastic Mr. Fox                   2009  Mr. Fox                     1
# From Dusk Till Dawn                 1996  Seth Gecko                  1
# Good Night, and Good Luck.          2005  Fred Friendly               1
# Gravity                             2013  Matt Kowalski               1
# Grizzly II: The Concert             1983  Ron                         1
# Hail, Caesar!                       2016  Baird Whitlock              1
# Intolerable Cruelty                 2003  Miles                       1
# ...

# %%
j1=c1.groupby(['year']).size().plot(kind='bar')

# %%
j1=c1.groupby(['year']).size().plot(ylim=0,c='g',style='*')

# %%
# to identify minimum and maximum score in movie roles by George Clooney

# %%
min1=c1.groupby(['year']).n.min()

# %%
min1
# Out:
# year
# 1983     NaN
# 1987    15.0
# 1988     2.0
# 1992     5.0
# 1996     1.0
# 1997     1.0
# 1998     1.0
# 1999     1.0
# 2000     1.0
# 2001     1.0
# 2002     1.0
# 2003     1.0
# 2004     3.0
# 2005     2.0
# 2006     1.0
# 2007     1.0
# 2008     1.0
# 2009     1.0
# 2010     1.0
# 2011     1.0
# 2013     2.0
# 2014     1.0
# 2015     1.0
# 2016     1.0
# Name: n, dtype: float64

# %%
max1=c1.groupby(['year']).n.max()

# %%
max1
# Out:
# year
# 1983     NaN
# 1987    15.0
# 1988     2.0
# 1992    23.0
# 1996     2.0
# 1997     2.0
# 1998    14.0
# 1999    11.0
# 2000     1.0
# 2001    36.0
# 2002    17.0
# 2003    22.0
# 2004     3.0
# 2005    15.0
# 2006     1.0
# 2007     6.0
# 2008     5.0
# 2009     1.0
# 2010     1.0
# 2011     2.0
# 2013     2.0
# 2014     1.0
# 2015     1.0
# 2016     2.0
# Name: n, dtype: float64

# %%
c1.groupby(['year']).size()
# Out:
# year
# 1983    1
# 1987    1
# 1988    1
# 1992    2
# 1996    3
# 1997    3
# 1998    2
# 1999    4
# 2000    2
# 2001    2
# 2002    3
# 2003    2
# 2004    1
# 2005    2
# 2006    1
# 2007    2
# 2008    2
# 2009    3
# 2010    3
# 2011    2
# 2013    1
# 2014    1
# 2015    1
# 2016    2
# dtype: int64

# %%
c1.groupby(c.year//10*10).size()
# Out:
# year
# 1980     3
# 1990    14
# 2000    20
# 2010    10
# dtype: int64

# %%
c1
# Out:
#                                      title  year            name   type  \
# 433326                      Batman & Robin  1997  George Clooney  actor
# 433327                      Batman & Robin  1997  George Clooney  actor
# 433328                  Burn After Reading  2008  George Clooney  actor
# 433329     Confessions of a Dangerous Mind  2002  George Clooney  actor
# 433330                             Curdled  1996  George Clooney  actor
# 433331                   Fantastic Mr. Fox  2009  George Clooney  actor
# 433332                 From Dusk Till Dawn  1996  George Clooney  actor
# 433333          Good Night, and Good Luck.  2005  George Clooney  actor
# 433334                             Gravity  2013  George Clooney  actor
# 433335             Grizzly II: The Concert  1983  George Clooney  actor
# 433336                       Hail, Caesar!  2016  George Clooney  actor
# 433337                 Intolerable Cruelty  2003  George Clooney  actor
# ...

# %%
c=cast

# %%
c.groupby([c.year//10*10,'type']).size()
# Out:
# year  type
# 1890  actor           2
#       actress         1
# 1900  actor          54
#       actress        16
# 1910  actor       27225
#       actress     15582
# 1920  actor       48340
#       actress     23753
# 1930  actor      150945
#       actress     49564
# 1940  actor      161923
#       actress     51396
# 1950  actor      157189
#       actress     57152
# 1960  actor      133570
#       actress     56826
# 1970  actor      152002
#       actress     65903
# 1980  actor      196282
#       actress     90283
# 1990  actor      262278
#       actress    123916
# 2000  actor      488494
#       actress    262514
# 2010  actor      739256
#       actress    414666
# 2020  actor          61
#       actress        50
# 2110  actor           2
#       actress         1
# dtype: int64

# %%
c=cast
c=c[(c.character=='Kermit the Frog') | (c.character=='Oscar the Grouch')]

# %%
c
# Out:
#                                                   title  year            name  \
# 977109                   An American Werewolf in London  1981      Jim Henson
# 977110                                 Follow That Bird  1985      Jim Henson
# 977115                           The Great Muppet Caper  1981      Jim Henson
# 977123                                 The Muppet Movie  1979      Jim Henson
# 977130                       The Muppets Take Manhattan  1984      Jim Henson
# 2143729                                Follow That Bird  1985  Caroll Spinney
# 2143732  Night at the Museum: Battle of the Smithsonian  2009  Caroll Spinney
# 2143734            The Adventures of Elmo in Grouchland  1999  Caroll Spinney
# 2143735                          The Great Muppet Caper  1981  Caroll Spinney
# 2423489                  Mr. Magorium's Wonder Emporium  2007  Steve Whitmire
# 2423490                          Muppet Treasure Island  1996  Steve Whitmire
# ...

# %%
d=c.groupby(['character',c.year//10*10]).size()

# %%
d
# Out:
# character         year
# Kermit the Frog   1970    1
#                   1980    4
#                   1990    2
#                   2000    1
#                   2010    1
# Oscar the Grouch  1980    2
#                   1990    1
#                   2000    1
# dtype: int64

# %%
magic=d.unstack()

# %%
magic
# Out:
# year              1970  1980  1990  2000  2010
# character
# Kermit the Frog    1.0   4.0   2.0   1.0   1.0
# Oscar the Grouch   NaN   2.0   1.0   1.0   NaN

# %%
magic1=d.unstack(0)
magic1
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               NaN
# 1980                   4.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               NaN

# %%
difference=d['Kermit the Frog']-d['Oscar the Grouch']

# %%
difference
# Out:
# year
# 1970    NaN
# 1980    2.0
# 1990    1.0
# 2000    0.0
# 2010    NaN
# dtype: float64

# %%
df=d.unstack(0)
df['Extra']=1
df1=df.set_index('Extra',drop=True,append=True)
df1.unstack(0)
# Out:
# character Kermit the Frog                     Oscar the Grouch                 \
# year                 1970 1980 1990 2000 2010             1970 1980 1990 2000
# Extra
# 1                     1.0  4.0  2.0  1.0  1.0              NaN  2.0  1.0  1.0
#
# character
# year      2010
# Extra
# 1          NaN
